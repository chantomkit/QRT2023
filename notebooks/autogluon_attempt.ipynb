# %%
import json
import os
os.chdir("..")

import pandas as pd
import numpy as np
from scipy.stats import spearmanr

from autogluon.tabular import TabularDataset, TabularPredictor
from autogluon.core.metrics import make_scorer

def metric_train(truth, output):
    return spearmanr(truth, output).correlation

ag_scorer = make_scorer(name='spearmanr',
                        score_func=metric_train,
                        optimum=1,
                        greater_is_better=True)

# %%
EXOTIC_PATH = "data/processed/exotic"
NON_EXOTIC_PATH = "data/processed/non_exotic"
FULL_PATH = "data/processed/full"
# either correlation-based or lasso feature selection
FEATURE_SELECTION_PATH = "features/all_features.json"
feature_selection = json.load(open(FEATURE_SELECTION_PATH, "r"))

de_train = pd.read_csv(f"{NON_EXOTIC_PATH}/median_imputed_train_de.csv").set_index("ID")
fr_train = pd.read_csv(f"{NON_EXOTIC_PATH}/median_imputed_train_fr.csv").set_index("ID")
exotic_train = pd.read_csv(f"{EXOTIC_PATH}/median_imputed_train.csv").set_index("ID")

de_test = pd.read_csv(f"{NON_EXOTIC_PATH}/median_imputed_test_de.csv").set_index("ID")
fr_test = pd.read_csv(f"{NON_EXOTIC_PATH}/median_imputed_test_fr.csv").set_index("ID")
exotic_test = pd.read_csv(f"{EXOTIC_PATH}/median_imputed_test.csv").set_index("ID")

full_train = pd.read_csv(f"{FULL_PATH}/median_imputed_train.csv").set_index("ID")

# %%
de_train_data = TabularDataset(de_train[feature_selection["de"] + ["RANK"]])
de_test_data = TabularDataset(de_test[feature_selection["de"]])

fr_train_data = TabularDataset(fr_train[feature_selection["fr"] + ["RANK"]])
fr_test_data = TabularDataset(fr_test[feature_selection["fr"]])

exotic_train_data = TabularDataset(exotic_train[feature_selection["exotic"] + ["RANK"]])
exotic_test_data = TabularDataset(exotic_test[feature_selection["exotic"]])

# %%
TRIAL = "all-features"

de_predictor = TabularPredictor(label='RANK', eval_metric=ag_scorer, path=f"AutogluonModels/{TRIAL}/de_model").fit(train_data=de_train_data, presets='medium_quality')
de_predictions = de_predictor.predict(de_test_data)

fr_predictor = TabularPredictor(label='RANK', eval_metric=ag_scorer, path=f"AutogluonModels/{TRIAL}/fr_model").fit(train_data=fr_train_data, presets='medium_quality')
fr_predictions = fr_predictor.predict(fr_test_data)

exotic_predictor = TabularPredictor(label='RANK', eval_metric=ag_scorer, path=f"AutogluonModels/{TRIAL}/exotic_model").fit(train_data=exotic_train_data, presets='medium_quality')
exotic_predictions = exotic_predictor.predict(exotic_test_data)
# Out:
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/all-features/de_model"
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/all-features/de_model/"
# AutoGluon Version:  0.8.2
# Python Version:     3.9.12
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 22.6.0: Wed Jul  5 22:17:35 PDT 2023; root:xnu-8796.141.3~6/RELEASE_ARM64_T8112
# Disk Space Avail:   400.22 GB / 494.38 GB (81.0%)
# Train Data Rows:    643
# Train Data Columns: 32
# Label Column: RANK
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1493.0, 9.0, 760.95257, 472.60538)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    607.23 MB
# 	Train Data (Original)  Memory Usage: 0.16 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 32 | ['DE_CONSUMPTION', 'FR_CONSUMPTION', 'DE_FR_EXCHANGE', 'FR_DE_EXCHANGE', 'DE_NET_EXPORT', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 32 | ['DE_CONSUMPTION', 'FR_CONSUMPTION', 'DE_FR_EXCHANGE', 'FR_DE_EXCHANGE', 'DE_NET_EXPORT', ...]
# 	0.0s = Fit runtime
# 	32 features in original data used to generate 32 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.16 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.04s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'spearmanr'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 514, Val Rows: 129
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.1312	 = Validation score   (spearmanr)
# 	5.88s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.1281	 = Validation score   (spearmanr)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	Warning: Exception caused LightGBMXT to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: LightGBM ...
# 	Warning: Exception caused LightGBM to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: RandomForestMSE ...
# 	0.3296	 = Validation score   (spearmanr)
# 	0.47s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.3259	 = Validation score   (spearmanr)
# 	0.86s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	0.315	 = Validation score   (spearmanr)
# 	0.24s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# Metric spearmanr is not supported by this model - using mean_squared_error instead
# No improvement since epoch 6: early stopping
# 	0.3703	 = Validation score   (spearmanr)
# 	1.02s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.4063	 = Validation score   (spearmanr)
# 	0.84s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.4405	 = Validation score   (spearmanr)
# 	1.41s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	Warning: Exception caused LightGBMLarge to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: WeightedEnsemble_L2 ...
# 	0.452	 = Validation score   (spearmanr)
# 	0.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 11.7s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/all-features/de_model/")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/all-features/fr_model"
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/all-features/fr_model/"
# AutoGluon Version:  0.8.2
# Python Version:     3.9.12
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 22.6.0: Wed Jul  5 22:17:35 PDT 2023; root:xnu-8796.141.3~6/RELEASE_ARM64_T8112
# Disk Space Avail:   400.22 GB / 494.38 GB (81.0%)
# Train Data Rows:    643
# Train Data Columns: 32
# Label Column: RANK
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1491.0, 1.0, 740.7605, 404.7123)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    597.52 MB
# 	Train Data (Original)  Memory Usage: 0.16 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 32 | ['DE_CONSUMPTION', 'FR_CONSUMPTION', 'DE_FR_EXCHANGE', 'FR_DE_EXCHANGE', 'DE_NET_EXPORT', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 32 | ['DE_CONSUMPTION', 'FR_CONSUMPTION', 'DE_FR_EXCHANGE', 'FR_DE_EXCHANGE', 'DE_NET_EXPORT', ...]
# 	0.0s = Fit runtime
# 	32 features in original data used to generate 32 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.16 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.04s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'spearmanr'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 514, Val Rows: 129
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	0.1429	 = Validation score   (spearmanr)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	0.1423	 = Validation score   (spearmanr)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	Warning: Exception caused LightGBMXT to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: LightGBM ...
# 	Warning: Exception caused LightGBM to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: RandomForestMSE ...
# 	0.2166	 = Validation score   (spearmanr)
# 	0.43s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.2036	 = Validation score   (spearmanr)
# 	0.53s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	0.2282	 = Validation score   (spearmanr)
# 	0.24s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# Metric spearmanr is not supported by this model - using mean_squared_error instead
# No improvement since epoch 6: early stopping
# 	0.2497	 = Validation score   (spearmanr)
# 	0.45s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost ...
# 	0.2245	 = Validation score   (spearmanr)
# 	0.78s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.261	 = Validation score   (spearmanr)
# 	0.81s	 = Training   runtime
# 	0.01s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	Warning: Exception caused LightGBMLarge to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: WeightedEnsemble_L2 ...
# 	0.3013	 = Validation score   (spearmanr)
# 	0.21s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 3.67s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/all-features/fr_model/")
# Warning: path already exists! This predictor may overwrite an existing predictor! path="AutogluonModels/all-features/exotic_model"
# Presets specified: ['medium_quality']
# Beginning AutoGluon training ...
# AutoGluon will save models to "AutogluonModels/all-features/exotic_model/"
# AutoGluon Version:  0.8.2
# Python Version:     3.9.12
# Operating System:   Darwin
# Platform Machine:   x86_64
# Platform Version:   Darwin Kernel Version 22.6.0: Wed Jul  5 22:17:35 PDT 2023; root:xnu-8796.141.3~6/RELEASE_ARM64_T8112
# Disk Space Avail:   400.22 GB / 494.38 GB (81.0%)
# Train Data Rows:    208
# Train Data Columns: 32
# Label Column: RANK
# Preprocessing data ...
# AutoGluon infers your prediction problem is: 'regression' (because dtype of label-column == float and many unique label-values observed).
# 	Label info (max, min, mean, stddev): (1494.0, 7.0, 726.7476, 374.96654)
# 	If 'regression' is not the correct problem_type, please manually specify the problem_type parameter during predictor init (You may specify problem_type as one of: ['binary', 'multiclass', 'regression'])
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    587.85 MB
# 	Train Data (Original)  Memory Usage: 0.05 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', []) : 32 | ['DE_CONSUMPTION', 'FR_CONSUMPTION', 'DE_FR_EXCHANGE', 'FR_DE_EXCHANGE', 'DE_NET_EXPORT', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', []) : 32 | ['DE_CONSUMPTION', 'FR_CONSUMPTION', 'DE_FR_EXCHANGE', 'FR_DE_EXCHANGE', 'DE_NET_EXPORT', ...]
# 	0.0s = Fit runtime
# 	32 features in original data used to generate 32 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.05 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.04s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'spearmanr'
# 	To change this, specify the eval_metric parameter of Predictor()
# Automatically generating train/validation split with holdout_frac=0.2, Train Rows: 166, Val Rows: 42
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': {},
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': {},
# 	'XGB': {},
# 	'FASTAI': {},
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# Fitting 11 L1 models ...
# Fitting model: KNeighborsUnif ...
# 	-0.0947	 = Validation score   (spearmanr)
# 	0.01s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: KNeighborsDist ...
# 	-0.0835	 = Validation score   (spearmanr)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMXT ...
# 	Warning: Exception caused LightGBMXT to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: LightGBM ...
# 	Warning: Exception caused LightGBM to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: RandomForestMSE ...
# 	-0.2312	 = Validation score   (spearmanr)
# 	0.23s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: CatBoost ...
# 	0.0699	 = Validation score   (spearmanr)
# 	0.37s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: ExtraTreesMSE ...
# 	-0.168	 = Validation score   (spearmanr)
# 	0.2s	 = Training   runtime
# 	0.02s	 = Validation runtime
# Fitting model: NeuralNetFastAI ...
# Metric spearmanr is not supported by this model - using mean_squared_error instead
# No improvement since epoch 1: early stopping
# 	-0.0113	 = Validation score   (spearmanr)
# 	0.47s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: XGBoost ...
# 	-0.0006	 = Validation score   (spearmanr)
# 	0.56s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: NeuralNetTorch ...
# 	0.2258	 = Validation score   (spearmanr)
# 	0.47s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting model: LightGBMLarge ...
# 	Warning: Exception caused LightGBMLarge to fail during training (ImportError)... Skipping this model.
# 		`import lightgbm` failed. If you are using Mac OSX, Please try 'brew install libomp'. Detailed info: dlopen(/Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so, 0x0006): Library not loaded: /usr/local/opt/libomp/lib/libomp.dylib
#   Referenced from: <D21A7969-4567-3BC7-94ED-6A9E83AE9D78> /Users/chantom/opt/anaconda3/lib/python3.9/site-packages/lightgbm/lib_lightgbm.so
#   Reason: tried: '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/System/Volumes/Preboot/Cryptexes/OS/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/opt/libomp/lib/libomp.dylib' (no such file), '/usr/local/lib/libomp.dylib' (no such file), '/usr/lib/libomp.dylib' (no such file, not in dyld cache)
# Fitting model: WeightedEnsemble_L2 ...
# 	0.2315	 = Validation score   (spearmanr)
# 	0.2s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 2.69s ... Best model: "WeightedEnsemble_L2"
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels/all-features/exotic_model/")

# %%
de_predictor.leaderboard()
# Out:
#                  model  score_val  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  WeightedEnsemble_L2   0.452007       0.008540  2.461281                0.001722           0.212031            2       True          9
# 1       NeuralNetTorch   0.440496       0.004858  1.410232                0.004858           1.410232            1       True          8
# 2              XGBoost   0.406334       0.001960  0.839018                0.001960           0.839018            1       True          7
# 3      NeuralNetFastAI   0.370254       0.008697  1.023602                0.008697           1.023602            1       True          6
# 4      RandomForestMSE   0.329562       0.020838  0.467790                0.020838           0.467790            1       True          3
# 5             CatBoost   0.325934       0.004383  0.858500                0.004383           0.858500            1       True          4
# 6        ExtraTreesMSE   0.315032       0.020996  0.244860                0.020996           0.244860            1       True          5
# 7       KNeighborsUnif   0.131203       0.009669  5.878124                0.009669           5.878124            1       True          1
# 8       KNeighborsDist   0.128064       0.001444  0.004298                0.001444           0.004298            1       True          2
#                  model  score_val  pred_time_val  fit_time  \
# 0  WeightedEnsemble_L2   0.452007       0.008540  2.461281
# 1       NeuralNetTorch   0.440496       0.004858  1.410232
# 2              XGBoost   0.406334       0.001960  0.839018
# 3      NeuralNetFastAI   0.370254       0.008697  1.023602
# 4      RandomForestMSE   0.329562       0.020838  0.467790
# 5             CatBoost   0.325934       0.004383  0.858500
# 6        ExtraTreesMSE   0.315032       0.020996  0.244860
# 7       KNeighborsUnif   0.131203       0.009669  5.878124
# 8       KNeighborsDist   0.128064       0.001444  0.004298
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.001722           0.212031            2       True
# 1                0.004858           1.410232            1       True
# 2                0.001960           0.839018            1       True
# 3                0.008697           1.023602            1       True
# 4                0.020838           0.467790            1       True
# 5                0.004383           0.858500            1       True
# 6                0.020996           0.244860            1       True
# 7                0.009669           5.878124            1       True
# 8                0.001444           0.004298            1       True
#
#    fit_order
# 0          9
# 1          8
# 2          7
# 3          6
# 4          3
# 5          4
# 6          5
# 7          1
# 8          2

# %%
fr_predictor.leaderboard()
# Out:
#                  model  score_val  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  WeightedEnsemble_L2   0.301303       0.011159  2.246138                0.000355           0.208593            2       True          9
# 1       NeuralNetTorch   0.261025       0.005466  0.813615                0.005466           0.813615            1       True          8
# 2      NeuralNetFastAI   0.249668       0.003586  0.446340                0.003586           0.446340            1       True          6
# 3        ExtraTreesMSE   0.228187       0.020364  0.241639                0.020364           0.241639            1       True          5
# 4              XGBoost   0.224526       0.001752  0.777590                0.001752           0.777590            1       True          7
# 5      RandomForestMSE   0.216590       0.020558  0.431229                0.020558           0.431229            1       True          3
# 6             CatBoost   0.203600       0.001259  0.534238                0.001259           0.534238            1       True          4
# 7       KNeighborsUnif   0.142876       0.003154  0.008117                0.003154           0.008117            1       True          1
# 8       KNeighborsDist   0.142255       0.001433  0.006490                0.001433           0.006490            1       True          2
#                  model  score_val  pred_time_val  fit_time  \
# 0  WeightedEnsemble_L2   0.301303       0.011159  2.246138
# 1       NeuralNetTorch   0.261025       0.005466  0.813615
# 2      NeuralNetFastAI   0.249668       0.003586  0.446340
# 3        ExtraTreesMSE   0.228187       0.020364  0.241639
# 4              XGBoost   0.224526       0.001752  0.777590
# 5      RandomForestMSE   0.216590       0.020558  0.431229
# 6             CatBoost   0.203600       0.001259  0.534238
# 7       KNeighborsUnif   0.142876       0.003154  0.008117
# 8       KNeighborsDist   0.142255       0.001433  0.006490
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.000355           0.208593            2       True
# 1                0.005466           0.813615            1       True
# 2                0.003586           0.446340            1       True
# 3                0.020364           0.241639            1       True
# 4                0.001752           0.777590            1       True
# 5                0.020558           0.431229            1       True
# 6                0.001259           0.534238            1       True
# 7                0.003154           0.008117            1       True
# 8                0.001433           0.006490            1       True
#
#    fit_order
# 0          9
# 1          8
# 2          6
# 3          5
# 4          7
# 5          3
# 6          4
# 7          1
# 8          2

# %%
exotic_predictor.leaderboard()
# Out:
#                  model  score_val  pred_time_val  fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  WeightedEnsemble_L2   0.231505       0.006360  1.229885                0.000340           0.200850            2       True          9
# 1       NeuralNetTorch   0.225833       0.004473  0.471790                0.004473           0.471790            1       True          8
# 2             CatBoost   0.069851       0.002469  0.366386                0.002469           0.366386            1       True          4
# 3              XGBoost  -0.000567       0.001547  0.557245                0.001547           0.557245            1       True          7
# 4      NeuralNetFastAI  -0.011263       0.004384  0.472588                0.004384           0.472588            1       True          6
# 5       KNeighborsDist  -0.083543       0.001774  0.004753                0.001774           0.004753            1       True          2
# 6       KNeighborsUnif  -0.094725       0.001798  0.005645                0.001798           0.005645            1       True          1
# 7        ExtraTreesMSE  -0.167977       0.016689  0.198145                0.016689           0.198145            1       True          5
# 8      RandomForestMSE  -0.231181       0.016239  0.229223                0.016239           0.229223            1       True          3
#                  model  score_val  pred_time_val  fit_time  \
# 0  WeightedEnsemble_L2   0.231505       0.006360  1.229885
# 1       NeuralNetTorch   0.225833       0.004473  0.471790
# 2             CatBoost   0.069851       0.002469  0.366386
# 3              XGBoost  -0.000567       0.001547  0.557245
# 4      NeuralNetFastAI  -0.011263       0.004384  0.472588
# 5       KNeighborsDist  -0.083543       0.001774  0.004753
# 6       KNeighborsUnif  -0.094725       0.001798  0.005645
# 7        ExtraTreesMSE  -0.167977       0.016689  0.198145
# 8      RandomForestMSE  -0.231181       0.016239  0.229223
#
#    pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  \
# 0                0.000340           0.200850            2       True
# 1                0.004473           0.471790            1       True
# 2                0.002469           0.366386            1       True
# 3                0.001547           0.557245            1       True
# 4                0.004384           0.472588            1       True
# 5                0.001774           0.004753            1       True
# 6                0.001798           0.005645            1       True
# 7                0.016689           0.198145            1       True
# 8                0.016239           0.229223            1       True
#
#    fit_order
# 0          9
# 1          8
# 2          4
# 3          7
# 4          6
# 5          2
# 6          1
# 7          5
# 8          3

# %%
full_test_pred = pd.concat([de_predictions, fr_predictions, exotic_predictions], axis=0)

# %%
sub_dummy = pd.read_csv("submissions/y_test_random_final.csv", index_col="ID", usecols=["ID"])
full_test_pred = sub_dummy.join(full_test_pred).rename({"RANK": "TARGET"}, axis=1)

# %%
full_test_pred.to_csv("submissions/sub32_autogluon_best_quality.csv")
